# %% [markdown]
# # 01 Data Understanding
#
# Initial verification of the Customer Support Ticket dataset.

# %% [markdown]
# ## Load Dataset

# %%
import pandas as pd

df = pd.read_csv('../data/raw/customer_support_tickets.csv')

print(df.shape)
df.head()

# %% [markdown]
# ## Dataset Information

# %%
df.info()

# %% [markdown]
# ## Descriptive Statistics

# %%
df.describe()

# %% [markdown]
# ## Missing Values

# %%
df.isnull().sum()
